# %%
import pandas as pd

# %%
firstGenPokemon = pd.read_html('https://pokemon.fandom.com/wiki/List_of_Generation_I_Pok%C3%A9mon')

# %%
len(firstGenPokemon)
# Out:
# 17

# %%
firstGenPokemon[2]
# Out:
#        #  Sprite        Name   Type 1  Type 2 Japanese Official rom.
# 0      1     NaN   Bulbasaur    Grass  Poison    フシギダネ   Fushigidane
# 1      2     NaN     Ivysaur    Grass  Poison    フシギソウ    Fushigisou
# 2      3     NaN    Venusaur    Grass  Poison    フシギバナ   Fushigibana
# 3      4     NaN  Charmander     Fire     NaN     ヒトカゲ      Hitokage
# 4      5     NaN  Charmeleon     Fire     NaN     リザード       Lizardo
# ..   ...     ...         ...      ...     ...      ...           ...
# 146  147     NaN     Dratini   Dragon     NaN    ミニリュウ       Miniryu
# 147  148     NaN   Dragonair   Dragon     NaN    ハクリュー       Hakuryu
# 148  149     NaN   Dragonite   Dragon  Flying    カイリュー        Kairyu
# 149  150     NaN      Mewtwo  Psychic     NaN    ミュウツー        Mewtwo
# 150  151     NaN         Mew  Psychic     NaN      ミュウ           Mew
#
# [151 rows x 7 columns]
